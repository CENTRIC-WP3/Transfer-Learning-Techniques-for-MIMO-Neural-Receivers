# %%
### CDL C to UMi


with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_tf_c2umi_all.pkl', 'rb') as f:
    bl_allc2umi = pickle.load(f)  
    
with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_tf_c2umi_fe.pkl', 'rb') as f:
    bl_c2umife = pickle.load(f) 


with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_tf_c2umi.pkl', 'rb') as f:
    bl_c2umi = pickle.load(f) 

    

with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_c2UMi_without_TL.pkl', 'rb') as f:
    bl_c2umi_WTL = pickle.load(f) 


with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_UMi_evaluate.pkl', 'rb') as f:
    bl_c2umi_eval = pickle.load(f) 

with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\figures_TL\\C_eval_UMi.pkl', 'rb') as f:
    C_evalUmi = pickle.load(f) 

    
#plt.figure(figsize=(10,6))
#
  



plt.semilogy(ebno_dbs,  bl_c2umi_WTL['neural-receiver'], 'o--r', label=r'Without TL: $|X_T| = 0.1|X_S|$' , linewidth = 2.5)
plt.semilogy(ebno_dbs,  C_evalUmi['neural-receiver'], 's--b', label=r'Model transfer: CDL-C $\rightarrow$ UMi' , linewidth = 2.5)
plt.semilogy(ebno_dbs,  bl_c2umife['neural-receiver'], 'P--g', label=f'Feature Extraction', linewidth = 2.5)
plt.semilogy(ebno_dbs,  bl_c2umi['neural-receiver'], 'p--c', label=f'Fine Tuning +' , linewidth = 2.5)
plt.semilogy(ebno_dbs, bl_allc2umi['neural-receiver'], 'd--m', label=r'Fine Tuning' , linewidth = 2.5)
plt.semilogy(ebno_dbs,  bl_c2umi_eval['neural-receiver'], '--k', label=r'Without TL: $|X_T| = |X_S|$' , linewidth = 2.5)


plt.xlabel(r"$E_b/N_0$ (dB)") 
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-5, 1.0))
plt.xlim((-4.0, 8.0))


plt.legend()
plt.tight_layout()

# %%
### CDL C to UMi



with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_tf_c2umi.pkl', 'rb') as f:
    bl_c2umi = pickle.load(f) 

with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\Desktop\\plots_C2UMi\\bler_UMi_evaluate.pkl', 'rb') as f:
    bl_c2umi_eval = pickle.load(f) 
    

with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\figures_TL\\bler_tf_c2umi_1500.pkl', 'rb') as f:
    bl_c2umi_1500 = pickle.load(f)  
    
    
with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\figures_TL\\bler_tf_c2umi_7500.pkl', 'rb') as f:
    bl_c2umi_7500 = pickle.load(f)  

with open('C:\\Users\\MW88BT\\OneDrive - Aalborg Universitet\\figures_TL\\bler_tf_c2umi_10500.pkl', 'rb') as f:
    bl_c2umi_10500 = pickle.load(f) 
    
# =============== using fine tuning plus ================ #
plt.semilogy(ebno_dbs,  bl_c2umi['neural-receiver'], 's--b', label=r'Fine Tuning + ($|X_T| =0.05|X_S|$)' , linewidth = 2.0)
plt.semilogy(ebno_dbs, bl_c2umi_1500['neural-receiver'], 'o--r', label=r'Fine Tuning +($|X_T| =0.1|X_S|$)' , linewidth = 2.0)
plt.semilogy(ebno_dbs, bl_c2umi_7500['neural-receiver'], 'P--g', label=r'Fine Tuning +($|X_T| =0.25|X_S|$)' , linewidth = 2.0)
plt.semilogy(ebno_dbs, bl_c2umi_10500['neural-receiver'], 'p--c', label=r'Fine Tuning + ($|X_T| = 0.35|X_S|$)' , linewidth = 2.0)
plt.semilogy(ebno_dbs,  bl_c2umi_eval['neural-receiver'], '--k', label=r'Without TL: $|X_T| = |X_S|$' , linewidth = 2.0)
# ================ =======================================#

plt.xlabel(r"$E_b/N_0$ (dB)") 
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-5, 1.0))
plt.xlim((-4.0, 8.0))


plt.legend()
plt.tight_layout()
